# %%
import json
import folium
import requests
import mimetypes
import http.client
import pandas as pd
from folium.plugins import HeatMap
from pandas.io.json import json_normalize

# %%
conn= http.client.HTTPSConnection("api.covid19api.com")
payload=''
headers={}
conn.request("GET","/summary",payload,headers)
res=conn.getresponse()
data=res.read().decode('UTF-8')

# %%
covid1=json.loads(data)

# %%
pd.json_normalize(covid1['Countries'],sep=",")
# Out:
#                                        ID                          Country  \
# 0    0f4c47b4-01ba-458c-a24d-4050d1881128                      Afghanistan
# 1    09050c57-0074-4b67-b734-84fb6f0fa305                          Albania
# 2    d876bcee-979d-4b60-b1ea-4c2644ad04d3                          Algeria
# 3    5bbf1d08-6eb2-40da-b790-c6b000ac9b6c                          Andorra
# 4    101e6f58-f9a8-41d0-ba92-c3ed6739a4fe                           Angola
# ..                                    ...                              ...
# 185  5255ae81-c39e-4baa-a3ce-a9db57902513  Venezuela (Bolivarian Republic)
# 186  a1aedad6-3a90-423d-875a-e06c0fa23635                         Viet Nam
# 187  3882d7d3-d134-4627-9bf3-292ed0d4dd7e                            Yemen
# 188  ed265fce-5787-4308-b5b5-74df47ae5c63                           Zambia
# 189  fefdbe36-dac2-42b3-b5d7-69f1c0c7f5a8                         Zimbabwe
#
#     CountryCode         Slug  NewConfirmed  TotalConfirmed  NewDeaths  \
# 0            AF  afghanistan            82           57242          8
# 1            AL      albania           125          128518          4
# 2            DZ      algeria           129          118645          4
# 3            AD      andorra            36           12581          1
# 4            AO       angola            92           23549          1
# ..          ...          ...           ...             ...        ...
# 185          VE    venezuela             0          174887          0
# 186          VN      vietnam            12            2705          0
# 187          YE        yemen            89            5446         19
# 188          ZM       zambia            35           90064          1
# 189          ZW     zimbabwe            19           37307          4
#
#      TotalDeaths  NewRecovered  TotalRecovered                      Date
# 0           2529            16           52005  2021-04-13T02:28:22.158Z
# 1           2321           546           98269  2021-04-13T02:28:22.158Z
# 2           3134           104           82704  2021-04-13T02:28:22.158Z
# 3            121            65           11890  2021-04-13T02:28:22.158Z
# 4            554            35           22093  2021-04-13T02:28:22.158Z
# ..           ...           ...             ...                       ...
# 185         1778             0          157486  2021-04-13T02:28:22.158Z
# 186           35            16            2445  2021-04-13T02:28:22.158Z
# 187         1068             6            2059  2021-04-13T02:28:22.158Z
# 188         1227            59           88077  2021-04-13T02:28:22.158Z
# 189         1542            28           34901  2021-04-13T02:28:22.158Z
#
# [190 rows x 11 columns]

# %% [markdown]
# ### Convert to Pandas DataFrame

# %%
df=pd.DataFrame(covid1['Countries'])
df
# Out:
#                                        ID                          Country  \
# 0    0f4c47b4-01ba-458c-a24d-4050d1881128                      Afghanistan
# 1    09050c57-0074-4b67-b734-84fb6f0fa305                          Albania
# 2    d876bcee-979d-4b60-b1ea-4c2644ad04d3                          Algeria
# 3    5bbf1d08-6eb2-40da-b790-c6b000ac9b6c                          Andorra
# 4    101e6f58-f9a8-41d0-ba92-c3ed6739a4fe                           Angola
# ..                                    ...                              ...
# 185  5255ae81-c39e-4baa-a3ce-a9db57902513  Venezuela (Bolivarian Republic)
# 186  a1aedad6-3a90-423d-875a-e06c0fa23635                         Viet Nam
# 187  3882d7d3-d134-4627-9bf3-292ed0d4dd7e                            Yemen
# 188  ed265fce-5787-4308-b5b5-74df47ae5c63                           Zambia
# 189  fefdbe36-dac2-42b3-b5d7-69f1c0c7f5a8                         Zimbabwe
#
#     CountryCode         Slug  NewConfirmed  TotalConfirmed  NewDeaths  \
# 0            AF  afghanistan            82           57242          8
# 1            AL      albania           125          128518          4
# 2            DZ      algeria           129          118645          4
# 3            AD      andorra            36           12581          1
# 4            AO       angola            92           23549          1
# ..          ...          ...           ...             ...        ...
# 185          VE    venezuela             0          174887          0
# 186          VN      vietnam            12            2705          0
# 187          YE        yemen            89            5446         19
# 188          ZM       zambia            35           90064          1
# 189          ZW     zimbabwe            19           37307          4
#
#      TotalDeaths  NewRecovered  TotalRecovered                      Date  \
# 0           2529            16           52005  2021-04-13T02:28:22.158Z
# 1           2321           546           98269  2021-04-13T02:28:22.158Z
# 2           3134           104           82704  2021-04-13T02:28:22.158Z
# 3            121            65           11890  2021-04-13T02:28:22.158Z
# 4            554            35           22093  2021-04-13T02:28:22.158Z
# ..           ...           ...             ...                       ...
# 185         1778             0          157486  2021-04-13T02:28:22.158Z
# 186           35            16            2445  2021-04-13T02:28:22.158Z
# 187         1068             6            2059  2021-04-13T02:28:22.158Z
# 188         1227            59           88077  2021-04-13T02:28:22.158Z
# 189         1542            28           34901  2021-04-13T02:28:22.158Z
#
#     Premium
# 0        {}
# 1        {}
# 2        {}
# 3        {}
# 4        {}
# ..      ...
# 185      {}
# 186      {}
# 187      {}
# 188      {}
# 189      {}
#
# [190 rows x 12 columns]

# %%
covid2=df.drop(columns=['ID','CountryCode','Slug','Date','Premium'],axis=1)
covid2
# Out:
#                              Country  NewConfirmed  TotalConfirmed  NewDeaths  \
# 0                        Afghanistan            82           57242          8
# 1                            Albania           125          128518          4
# 2                            Algeria           129          118645          4
# 3                            Andorra            36           12581          1
# 4                             Angola            92           23549          1
# ..                               ...           ...             ...        ...
# 185  Venezuela (Bolivarian Republic)             0          174887          0
# 186                         Viet Nam            12            2705          0
# 187                            Yemen            89            5446         19
# 188                           Zambia            35           90064          1
# 189                         Zimbabwe            19           37307          4
#
#      TotalDeaths  NewRecovered  TotalRecovered
# 0           2529            16           52005
# 1           2321           546           98269
# 2           3134           104           82704
# 3            121            65           11890
# 4            554            35           22093
# ..           ...           ...             ...
# 185         1778             0          157486
# 186           35            16            2445
# 187         1068             6            2059
# 188         1227            59           88077
# 189         1542            28           34901
#
# [190 rows x 7 columns]

# %%
m=folium.Map(tiles="Stamen Terrain",min_zoom=1.5)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
url='https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
country_shapes=f'{url}/world-countries.json'

# %%
folium.Choropleth(
    geo_data=country_shapes,
    min_zomm=2,
    name='Covid-19',
    data=covid2,
    columns=['Country','TotalConfirmed'],
    key_on='feature.properties.name',
    fill_color='OrRd',
    nan_fill_color='black',
    legend_name='Total COnfirmed Covid Cases',
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
covid2.update(covid2['TotalConfirmed'].map('Total Confirmed:{}'.format))
covid2.update(covid2['TotalRecovered'].map('Total Recovered:{}'.format))

# %% [markdown]
# coordinates of countries: https://raw.githubusercontent.com/VinitaSilaparasetty/covid-map/master/country-coordinates-world.csv

# %%
coordinates=pd.read_csv('https://raw.githubusercontent.com/VinitaSilaparasetty/covid-map/master/country-coordinates-world.csv')
coordinates
# Out:
#       latitude   longitude            Country
# 0    33.939110   67.709953        Afghanistan
# 1    41.153332   20.168331            Albania
# 2    28.033886    1.659626            Algeria
# 3   -14.270972 -170.132217     American Samoa
# 4    42.546245    1.601554            Andorra
# ..         ...         ...                ...
# 239 -13.768752 -177.156097  Wallis and Futuna
# 240  24.215527  -12.885834     Western Sahara
# 241  15.552727   48.516388              Yemen
# 242 -13.133897   27.849332             Zambia
# 243 -19.015438   29.154857           Zimbabwe
#
# [244 rows x 3 columns]

# %%
covid_final=pd.merge(covid2,coordinates,on='Country')

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude,point.longitude],
                       radius=5,
                       weight=2,
                       popup=[point.Country,point.TotalConfirmed,point.TotalRecovered],
                       fill_color='#000000').add_to(m)

# %%
covid_final.apply(plotDot,axis=1)
m.fit_bounds(m.get_bounds())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Generate Base Map

# %%
m1=folium.Map(tiles='StamenToner',min_zoom=2)
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
deaths=covid_final['TotalDeaths'].astype(float)

# %%
lat=covid_final['latitude'].astype(float)

# %%
lon=covid_final['longitude'].astype(float)

# %%
m1.add_child(HeatMap(zip(lat,lon,deaths),radius=0))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def plotDot(point):
    folium.CircleMarker(location=[point.latitude,point.longitude],
                       radius=5,
                       weight=2,
                       popup=[point.Country,point.TotalDeaths],
                       fill_color='#000000').add_to(m1)
    
covid_final.apply(plotDot,axis=1)
m1.fit_bounds(m1.get_bounds())
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
